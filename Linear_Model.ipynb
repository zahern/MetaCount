# %% [markdown]
# # Install

# %%
# !pip install metacountregressor --upgrade --quiet

# %% [markdown]
# # Load in Data

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from metacountregressor.solution import ObjectiveFunction
from metacountregressor.metaheuristics import (harmony_search,
                                            differential_evolution,
                                            simulated_annealing)


df = pd.read_csv('data/Real estate.csv')

# %% [markdown]
# # Prepare X and Y

# %%
y = df['Y house price of unit area']
X = df.drop(['No', 'Y house price of unit area'], axis =1)


print("X=", X.shape, "\ny=", y.shape)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
# Out:
# X= (414, 6)
# y= (414,)

# %% [markdown]
# # Simple Linear Regression Search Setup

# %%
# Define example arguments (defaults for clarity); see documentation for details
arguments = {
    'algorithm': 'hs',           # Harmony Search algorithm
    'test_percentage': 0,     # 15% of data for testing
    'complexity_level': 2,        # Complexity of the test
    'instance_number': 1,        # Instance number
    'val_percentage': 0,      # 15% of data for validation
    '_obj_1': 'bic',              # First objective: Bayesian Information Criterion
    '_obj_2': 'MAE',       # Second objective: Root Mean Square Error on Test data
    '_max_time': 6,               # Maximum time for the process (seconds)
    'linear_model': True,        # Use linear model, False for Poisson regression
    'is_multi': False            # Single output
}
# Fit the model using MetaCountRegressor
obj_fun = ObjectiveFunction(X, y, **arguments)

# Use Harmony Search metaheuristic to optimize the objective function
results = harmony_search(obj_fun)
# Out:
# test percentage is 0, please enter arg test_percentage as decimal, eg 0.8
# continuing single objective
# No Panels. Grouped Random Paramaters Will not be estimated
# Setup Complete...
# The type of models possible will consider: Poisson, NB
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136112.20491134963
# --------------------------------------------------------------------------------
# bic: 272255.54
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +------------------------+---------+--------+----------+----------+------------+
# |         Effect         | $\tau$  | Coeff  | Std. Err | z-values | Prob |z|>Z |
# +========================+=========+========+==========+==========+============+
# | const                  | no      | -6.00  |   0.53   |  -11.32  | 0.00***    |
# +------------------------+---------+--------+----------+----------+------------+
# | X1 transaction date    | log     | -45.18 |   1.31   |  -34.58  | 0.00***    |
# +------------------------+---------+--------+----------+----------+------------+
# | X2 house age           | arcsinh | -0.11  |   0.37   |  -0.29   | 0.77       |
# +------------------------+---------+--------+----------+----------+------------+
# | X4 number of           | arcsinh |  0.16  |   0.50   |   0.33   | 0.74       |
# | convenience stores     |         |        |          |          |            |
# +------------------------+---------+--------+----------+----------+------------+
# | X5 latitude            | no      | 14.15  |   0.37   |  37.75   | 0.00***    |
# +------------------------+---------+--------+----------+----------+------------+
# zero-size array to reduction operation maximum which has no identity
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136155.8612886102
# --------------------------------------------------------------------------------
# bic: 272342.85
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +------------------------+--------+---------+----------+----------+------------+
# |         Effect         | $\tau$ |  Coeff  | Std. Err | z-values | Prob |z|>Z |
# +========================+========+=========+==========+==========+============+
# | const                  | no     | -25.17  |   1.02   |  -24.76  | 0.00***    |
# +------------------------+--------+---------+----------+----------+------------+
# | X1 transaction date    | log    | -103.14 |   1.67   |  -50.00  | 0.00***    |
# +------------------------+--------+---------+----------+----------+------------+
# | X3 distance to the     | log    |  -0.25  |   4.64   |  -0.05   | 0.96       |
# | nearest MRT station    |        |         |          |          |            |
# +------------------------+--------+---------+----------+----------+------------+
# | X4 number of           | no     |  0.01   |   1.52   |   0.01   | 0.99       |
# | convenience stores     |        |         |          |          |            |
# +------------------------+--------+---------+----------+----------+------------+
# | X6 longitude           | sqrt   |  73.93  |   0.00   |  50.00   | 0.00***    |
# +------------------------+--------+---------+----------+----------+------------+
# | nb                     |        |  1.00   |   0.00   |  50.00   | 0.00***    |
# +------------------------+--------+---------+----------+----------+------------+
# zero-size array to reduction operation maximum which has no identity
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136596.94136099058
# --------------------------------------------------------------------------------
# bic: 273225.01
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-----------------------+---------+---------+----------+----------+------------+
# |        Effect         | $\tau$  |  Coeff  | Std. Err | z-values | Prob |z|>Z |
# +=======================+=========+=========+==========+==========+============+
# | const                 | no      | -37.88  |   1.02   |  -37.19  | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | X2 house age          | no      |  -0.01  |   0.29   |  -0.03   | 0.98       |
# +-----------------------+---------+---------+----------+----------+------------+
# | X3 distance to the    | sqrt    |  -0.02  |   0.18   |  -0.10   | 0.92       |
# | nearest MRT station   |         |         |          |          |            |
# +-----------------------+---------+---------+----------+----------+------------+
# | X5 latitude           | arcsinh | 248.34  |   0.79   |  50.00   | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | X6 longitude          | log     | -193.24 |   0.00   |  -50.00  | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | nb                    |         |  1.00   |   0.00   |  50.00   | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# zero-size array to reduction operation maximum which has no identity
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136155.6737756757
# --------------------------------------------------------------------------------
# bic: 272330.43
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-------------------------+---------+-------+----------+----------+------------+
# |         Effect          | $\tau$  | Coeff | Std. Err | z-values | Prob |z|>Z |
# +=========================+=========+=======+==========+==========+============+
# | const                   | no      | 4.07  |  13.37   |   0.30   | 0.76       |
# +-------------------------+---------+-------+----------+----------+------------+
# | X3 distance to the      | sqrt    | -0.02 |   0.27   |  -0.07   | 0.94       |
# | nearest MRT station     |         |       |          |          |            |
# +-------------------------+---------+-------+----------+----------+------------+
# | X4 number of            | arcsinh | 0.05  |   0.00   |  12.01   | 0.00***    |
# | convenience stores      |         |       |          |          |            |
# +-------------------------+---------+-------+----------+----------+------------+
# | nb                      |         | 1.00  |   0.00   |  50.00   | 0.00***    |
# +-------------------------+---------+-------+----------+----------+------------+
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136106.32387178112
# --------------------------------------------------------------------------------
# bic: 272245.28
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-------------------------+--------+--------+----------+----------+------------+
# |         Effect          | $\tau$ | Coeff  | Std. Err | z-values | Prob |z|>Z |
# +=========================+========+========+==========+==========+============+
# | const                   | no     | -14.61 |  21.50   |  -0.68   | 0.50       |
# +-------------------------+--------+--------+----------+----------+------------+
# | X1 transaction date     | log    | 106.78 |  99.62   |   1.07   | 0.28       |
# +-------------------------+--------+--------+----------+----------+------------+
# | X2 house age            | no     | -0.01  |   0.04   |  -0.18   | 0.86       |
# +-------------------------+--------+--------+----------+----------+------------+
# | X3 distance to the      | sqrt   | -0.02  |   0.04   |  -0.54   | 0.59       |
# | nearest MRT station     |        |        |          |          |            |
# +-------------------------+--------+--------+----------+----------+------------+
# | X6 longitude            | sqrt   | -71.96 |  66.77   |  -1.08   | 0.28       |
# +-------------------------+--------+--------+----------+----------+------------+
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136111.39750308366
# --------------------------------------------------------------------------------
# bic: 272248.90
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-------------------------+---------+-------+----------+----------+------------+
# |         Effect          | $\tau$  | Coeff | Std. Err | z-values | Prob |z|>Z |
# +=========================+=========+=======+==========+==========+============+
# | const                   | no      | 0.12  |   0.66   |   0.18   | 0.85       |
# +-------------------------+---------+-------+----------+----------+------------+
# | X3 distance to the      | sqrt    | -0.02 |   0.07   |  -0.25   | 0.80       |
# | nearest MRT station     |         |       |          |          |            |
# +-------------------------+---------+-------+----------+----------+------------+
# | X4 number of            | arcsinh | 0.05  |   1.04   |   0.05   | 0.96       |
# | convenience stores      |         |       |          |          |            |
# +-------------------------+---------+-------+----------+----------+------------+
# | X6 longitude            | arcsinh | 0.72  |   0.52   |   1.38   | 0.17       |
# +-------------------------+---------+-------+----------+----------+------------+
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136108.06134171557
# --------------------------------------------------------------------------------
# bic: 272241.73
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-------------------------+---------+-------+----------+----------+------------+
# |         Effect          | $\tau$  | Coeff | Std. Err | z-values | Prob |z|>Z |
# +=========================+=========+=======+==========+==========+============+
# | const                   | no      | 0.18  |   0.98   |   0.19   | 0.85       |
# +-------------------------+---------+-------+----------+----------+------------+
# | X2 house age            | arcsinh | -0.06 |   0.41   |  -0.14   | 0.89       |
# +-------------------------+---------+-------+----------+----------+------------+
# | X3 distance to the      | sqrt    | -0.02 |   0.04   |  -0.51   | 0.61       |
# | nearest MRT station     |         |       |          |          |            |
# +-------------------------+---------+-------+----------+----------+------------+
# | X6 longitude            | log     | 0.88  |   0.37   |   2.37   | 0.02*      |
# +-------------------------+---------+-------+----------+----------+------------+
# zero-size array to reduction operation maximum which has no identity
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136484.66155032316
# --------------------------------------------------------------------------------
# bic: 272987.40
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +--------------+---------+---------+----------+----------+------------+
# |    Effect    | $\tau$  |  Coeff  | Std. Err | z-values | Prob |z|>Z |
# +==============+=========+=========+==========+==========+============+
# | const        | no      | -33.34  |   0.99   |  -33.59  | 0.00***    |
# +--------------+---------+---------+----------+----------+------------+
# | X5 latitude  | sqrt    | 175.28  |   0.79   |  50.00   | 0.00***    |
# +--------------+---------+---------+----------+----------+------------+
# | X6 longitude | arcsinh | -152.70 |   0.00   |  -50.00  | 0.00***    |
# +--------------+---------+---------+----------+----------+------------+
# | nb           |         |  1.00   |   0.00   |  50.00   | 0.00***    |
# +--------------+---------+---------+----------+----------+------------+
# zero-size array to reduction operation maximum which has no identity
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136155.89771606523
# --------------------------------------------------------------------------------
# bic: 272330.87
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +--------------------------+--------+-------+----------+----------+------------+
# |          Effect          | $\tau$ | Coeff | Std. Err | z-values | Prob |z|>Z |
# +==========================+========+=======+==========+==========+============+
# | const                    | no     | 0.09  |   1.05   |   0.09   | 0.93       |
# +--------------------------+--------+-------+----------+----------+------------+
# | X1 transaction date      | log    | 0.72  |   2.60   |   0.28   | 0.78       |
# +--------------------------+--------+-------+----------+----------+------------+
# | X3 distance to the       | log    | -0.30 |   0.00   |  -50.00  | 0.00***    |
# | nearest MRT station      |        |       |          |          |            |
# +--------------------------+--------+-------+----------+----------+------------+
# | nb                       |        | 1.00  |   0.00   |  50.00   | 0.00***    |
# +--------------------------+--------+-------+----------+----------+------------+
# zero-size array to reduction operation maximum which has no identity
# --------------------------------------------------------------------------------
# Log-Likelihood:  -143640.72841050883
# --------------------------------------------------------------------------------
# bic: 287300.03
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +--------------+--------+----------+----------+----------+------------+
# |    Effect    | $\tau$ |  Coeff   | Std. Err | z-values | Prob |z|>Z |
# +==============+========+==========+==========+==========+============+
# | const        | no     | -6194.90 |   1.00   |  -50.00  | 0.00***    |
# +--------------+--------+----------+----------+----------+------------+
# | X2 house age | no     |  -0.00   |   0.26   |  -0.02   | 0.99       |
# +--------------+--------+----------+----------+----------+------------+
# | X6 longitude | log    | 1289.13  |   0.00   |  50.00   | 0.00***    |
# +--------------+--------+----------+----------+----------+------------+
# | nb           |        |   1.00   |   0.00   |  50.00   | 0.00***    |
# +--------------+--------+----------+----------+----------+------------+
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136105.67368863453
# --------------------------------------------------------------------------------
# bic: 272250.50
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +--------------------------+--------+-------+----------+----------+------------+
# |          Effect          | $\tau$ | Coeff | Std. Err | z-values | Prob |z|>Z |
# +==========================+========+=======+==========+==========+============+
# | const                    | no     | -0.27 |   2.52   |  -0.11   | 0.91       |
# +--------------------------+--------+-------+----------+----------+------------+
# | X1 transaction date      | sqrt   | -6.26 |  25.65   |  -0.24   | 0.81       |
# +--------------------------+--------+-------+----------+----------+------------+
# | X2 house age             | no     | -0.01 |   0.04   |  -0.16   | 0.87       |
# +--------------------------+--------+-------+----------+----------+------------+
# | X3 distance to the       | log    | -0.18 |   0.81   |  -0.23   | 0.82       |
# | nearest MRT station      |        |       |          |          |            |
# +--------------------------+--------+-------+----------+----------+------------+
# | X4 number of convenience | no     | 0.01  |   0.26   |   0.05   | 0.96       |
# | stores                   |        |       |          |          |            |
# +--------------------------+--------+-------+----------+----------+------------+
# | X5 latitude              | no     | 11.46 |  46.15   |   0.25   | 0.80       |
# +--------------------------+--------+-------+----------+----------+------------+
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136148.13316927818
# --------------------------------------------------------------------------------
# bic: 272320.37
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +---------------------+--------+--------+----------+----------+------------+
# |       Effect        | $\tau$ | Coeff  | Std. Err | z-values | Prob |z|>Z |
# +=====================+========+========+==========+==========+============+
# | const               | no     | -2.66  |   1.13   |  -2.36   | 0.02*      |
# +---------------------+--------+--------+----------+----------+------------+
# | X1 transaction date | log    | -19.99 |   1.72   |  -11.60  | 0.00***    |
# +---------------------+--------+--------+----------+----------+------------+
# | X5 latitude         | no     | 17.49  |   0.95   |  18.37   | 0.00***    |
# +---------------------+--------+--------+----------+----------+------------+
# | X6 longitude        | sqrt   | -25.24 |   1.13   |  -22.43  | 0.00***    |
# +---------------------+--------+--------+----------+----------+------------+
# zero-size array to reduction operation maximum which has no identity
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136156.2949552567
# --------------------------------------------------------------------------------
# bic: 272338.19
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-------------------------+---------+-------+----------+----------+------------+
# |         Effect          | $\tau$  | Coeff | Std. Err | z-values | Prob |z|>Z |
# +=========================+=========+=======+==========+==========+============+
# | const                   | no      | 0.15  |   1.06   |   0.14   | 0.89       |
# +-------------------------+---------+-------+----------+----------+------------+
# | X2 house age            | arcsinh | -0.08 |   3.00   |  -0.03   | 0.98       |
# +-------------------------+---------+-------+----------+----------+------------+
# | X4 number of            | arcsinh | 0.23  |   2.50   |   0.09   | 0.93       |
# | convenience stores      |         |       |          |          |            |
# +-------------------------+---------+-------+----------+----------+------------+
# | X6 longitude            | log     | 0.70  |   0.00   |  50.00   | 0.00***    |
# +-------------------------+---------+-------+----------+----------+------------+
# | nb                      |         | 1.00  |   0.00   |  50.00   | 0.00***    |
# +-------------------------+---------+-------+----------+----------+------------+
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136900.93767900844
# --------------------------------------------------------------------------------
# bic: 273833.50
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-----------------------+---------+---------+----------+----------+------------+
# |        Effect         | $\tau$  |  Coeff  | Std. Err | z-values | Prob |z|>Z |
# +=======================+=========+=========+==========+==========+============+
# | const                 | no      | -797.89 |   1.18   |  -50.00  | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | X1 transaction date   | sqrt    |  17.88  |   0.05   |  50.00   | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | X2 house age          | arcsinh |  -0.08  |   0.36   |  -0.22   | 0.83       |
# +-----------------------+---------+---------+----------+----------+------------+
# | X3 distance to the    | sqrt    |  -0.02  |   0.06   |  -0.32   | 0.75       |
# | nearest MRT station   |         |         |          |          |            |
# +-----------------------+---------+---------+----------+----------+------------+
# | X4 number of          | no      |  0.01   |   0.23   |   0.05   | 0.96       |
# | convenience stores    |         |         |          |          |            |
# +-----------------------+---------+---------+----------+----------+------------+
# --------------------------------------------------------------------------------
# Log-Likelihood:  -137584.81592976142
# --------------------------------------------------------------------------------
# bic: 275195.74
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-----------------------+--------+----------+----------+----------+------------+
# |        Effect         | $\tau$ |  Coeff   | Std. Err | z-values | Prob |z|>Z |
# +=======================+========+==========+==========+==========+============+
# | const                 | no     | -1132.37 | 6604.54  |  -0.17   | 0.86       |
# +-----------------------+--------+----------+----------+----------+------------+
# | X2 house age          | no     |  -0.01   |   0.03   |  -0.22   | 0.82       |
# +-----------------------+--------+----------+----------+----------+------------+
# | X3 distance to the    | log    |  -0.21   |   0.41   |  -0.52   | 0.60       |
# | nearest MRT station   |        |          |          |          |            |
# +-----------------------+--------+----------+----------+----------+------------+
# | X5 latitude           | log    |  349.24  | 2027.46  |   0.17   | 0.86       |
# +-----------------------+--------+----------+----------+----------+------------+
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136116.3605192597
# --------------------------------------------------------------------------------
# bic: 272265.35
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-------------------------+---------+-------+----------+----------+------------+
# |         Effect          | $\tau$  | Coeff | Std. Err | z-values | Prob |z|>Z |
# +=========================+=========+=======+==========+==========+============+
# | const                   | no      | 0.16  |   1.00   |   0.16   | 0.88       |
# +-------------------------+---------+-------+----------+----------+------------+
# | X2 house age            | arcsinh | -0.06 |   0.43   |  -0.14   | 0.89       |
# +-------------------------+---------+-------+----------+----------+------------+
# | X3 distance to the      | log     | -0.21 |   0.80   |  -0.26   | 0.80       |
# | nearest MRT station     |         |       |          |          |            |
# +-------------------------+---------+-------+----------+----------+------------+
# | X4 number of            | no      | 0.02  |   0.25   |   0.07   | 0.94       |
# | convenience stores      |         |       |          |          |            |
# +-------------------------+---------+-------+----------+----------+------------+
# | X6 longitude            | arcsinh | 0.89  |   1.01   |   0.88   | 0.38       |
# +-------------------------+---------+-------+----------+----------+------------+
# --------------------------------------------------------------------------------
# Log-Likelihood:  -137166.9737601955
# --------------------------------------------------------------------------------
# bic: 274359.05
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +----------------------+---------+----------+----------+----------+------------+
# |        Effect        | $\tau$  |  Coeff   | Std. Err | z-values | Prob |z|>Z |
# +======================+=========+==========+==========+==========+============+
# | const                | no      | -1043.75 |   0.15   |  -50.00  | 0.00***    |
# +----------------------+---------+----------+----------+----------+------------+
# | X1 transaction date  | sqrt    |  23.34   |   0.01   |  50.00   | 0.00***    |
# +----------------------+---------+----------+----------+----------+------------+
# | X2 house age         | arcsinh |  -0.10   |   0.34   |  -0.30   | 0.77       |
# +----------------------+---------+----------+----------+----------+------------+
# | X4 number of         | arcsinh |   0.22   |   0.27   |   0.83   | 0.41       |
# | convenience stores   |         |          |          |          |            |
# +----------------------+---------+----------+----------+----------+------------+
# zero-size array to reduction operation maximum which has no identity
# --------------------------------------------------------------------------------
# Log-Likelihood:  -138435.05205493455
# --------------------------------------------------------------------------------
# bic: 276888.68
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +--------------+---------+----------+----------+----------+------------+
# |    Effect    | $\tau$  |  Coeff   | Std. Err | z-values | Prob |z|>Z |
# +==============+=========+==========+==========+==========+============+
# | const        | no      | -1742.60 |   1.28   |  -50.00  | 0.00***    |
# +--------------+---------+----------+----------+----------+------------+
# | X2 house age | arcsinh |  -0.12   |   2.89   |  -0.04   | 0.97       |
# +--------------+---------+----------+----------+----------+------------+
# | X5 latitude  | log     |  536.28  |   0.00   |  50.00   | 0.00***    |
# +--------------+---------+----------+----------+----------+------------+
# | nb           |         |   1.00   |   0.00   |  50.00   | 0.00***    |
# +--------------+---------+----------+----------+----------+------------+
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136780.5487335781
# --------------------------------------------------------------------------------
# bic: 273592.23
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-----------------------+---------+---------+----------+----------+------------+
# |        Effect         | $\tau$  |  Coeff  | Std. Err | z-values | Prob |z|>Z |
# +=======================+=========+=========+==========+==========+============+
# | const                 | no      | -156.71 |   1.17   |  -50.00  | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | X1 transaction date   | arcsinh | -170.28 |   0.00   |  -50.00  | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | X2 house age          | arcsinh |  -0.07  |   0.40   |  -0.17   | 0.87       |
# +-----------------------+---------+---------+----------+----------+------------+
# | X4 number of          | arcsinh |  0.23   |   0.45   |   0.51   | 0.61       |
# | convenience stores    |         |         |          |          |            |
# +-----------------------+---------+---------+----------+----------+------------+
# | X6 longitude          | log     | 327.27  |   0.46   |  50.00   | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# --------------------------------------------------------------------------------
# Log-Likelihood:  -137053.82438250858
# --------------------------------------------------------------------------------
# bic: 274125.73
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +---------------------+--------+---------+----------+----------+------------+
# |       Effect        | $\tau$ |  Coeff  | Std. Err | z-values | Prob |z|>Z |
# +=====================+========+=========+==========+==========+============+
# | const               | no     | -419.27 |   2.24   |  -50.00  | 0.00***    |
# +---------------------+--------+---------+----------+----------+------------+
# | X1 transaction date | sqrt   | -25.32  |   0.01   |  -50.00  | 0.00***    |
# +---------------------+--------+---------+----------+----------+------------+
# | X5 latitude         | log    | 478.67  |   0.75   |  50.00   | 0.00***    |
# +---------------------+--------+---------+----------+----------+------------+
# zero-size array to reduction operation maximum which has no identity
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136155.89773149334
# --------------------------------------------------------------------------------
# bic: 272330.37
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-------------------------+---------+-------+----------+----------+------------+
# |         Effect          | $\tau$  | Coeff | Std. Err | z-values | Prob |z|>Z |
# +=========================+=========+=======+==========+==========+============+
# | const                   | no      | 0.17  |   0.01   |  23.41   | 0.00***    |
# +-------------------------+---------+-------+----------+----------+------------+
# | X3 distance to the      | log     | -0.30 |   1.81   |  -0.17   | 0.87       |
# | nearest MRT station     |         |       |          |          |            |
# +-------------------------+---------+-------+----------+----------+------------+
# | X6 longitude            | arcsinh | 0.98  |   0.00   |  50.00   | 0.00***    |
# +-------------------------+---------+-------+----------+----------+------------+
# | nb                      |         | 1.00  |   0.00   |  50.00   | 0.00***    |
# +-------------------------+---------+-------+----------+----------+------------+
# zero-size array to reduction operation maximum which has no identity
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136663.16689583208
# --------------------------------------------------------------------------------
# bic: 273357.46
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-----------------------+---------+---------+----------+----------+------------+
# |        Effect         | $\tau$  |  Coeff  | Std. Err | z-values | Prob |z|>Z |
# +=======================+=========+=========+==========+==========+============+
# | const                 | no      | -300.01 |   1.00   |  -50.00  | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | X1 transaction date   | log     | -109.47 |   1.10   |  -50.00  | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | X2 house age          | arcsinh |  -0.09  |   2.91   |  -0.03   | 0.98       |
# +-----------------------+---------+---------+----------+----------+------------+
# | X4 number of          | no      |  0.07   |   0.98   |   0.08   | 0.94       |
# | convenience stores    |         |         |          |          |            |
# +-----------------------+---------+---------+----------+----------+------------+
# | X6 longitude          | arcsinh | 206.88  |   0.00   |  50.00   | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | nb                    |         |  1.00   |   0.00   |  50.00   | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# zero-size array to reduction operation maximum which has no identity
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136155.59226075932
# --------------------------------------------------------------------------------
# bic: 272336.79
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-------------------------+---------+-------+----------+----------+------------+
# |         Effect          | $\tau$  | Coeff | Std. Err | z-values | Prob |z|>Z |
# +=========================+=========+=======+==========+==========+============+
# | const                   | no      | 0.03  |   1.01   |   0.03   | 0.97       |
# +-------------------------+---------+-------+----------+----------+------------+
# | X2 house age            | arcsinh | -0.07 |   2.78   |  -0.02   | 0.98       |
# +-------------------------+---------+-------+----------+----------+------------+
# | X3 distance to the      | sqrt    | -0.02 |   0.20   |  -0.10   | 0.92       |
# | nearest MRT station     |         |       |          |          |            |
# +-------------------------+---------+-------+----------+----------+------------+
# | X6 longitude            | sqrt    | 0.40  |   0.00   |  50.00   | 0.00***    |
# +-------------------------+---------+-------+----------+----------+------------+
# | nb                      |         | 1.00  |   0.00   |  50.00   | 0.00***    |
# +-------------------------+---------+-------+----------+----------+------------+
# zero-size array to reduction operation maximum which has no identity
# --------------------------------------------------------------------------------
# Log-Likelihood:  -137330.6879206391
# --------------------------------------------------------------------------------
# bic: 274685.98
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +---------------------+---------+---------+----------+----------+------------+
# |       Effect        | $\tau$  |  Coeff  | Std. Err | z-values | Prob |z|>Z |
# +=====================+=========+=========+==========+==========+============+
# | const               | no      | -170.62 |   1.00   |  -50.00  | 0.00***    |
# +---------------------+---------+---------+----------+----------+------------+
# | X1 transaction date | arcsinh | -354.54 |   0.99   |  -50.00  | 0.00***    |
# +---------------------+---------+---------+----------+----------+------------+
# | X2 house age        | arcsinh |  -0.06  |   2.79   |  -0.02   | 0.98       |
# +---------------------+---------+---------+----------+----------+------------+
# | X6 longitude        | log     | 648.32  |   0.00   |  50.00   | 0.00***    |
# +---------------------+---------+---------+----------+----------+------------+
# | nb                  |         |  1.00   |   0.00   |  50.00   | 0.00***    |
# +---------------------+---------+---------+----------+----------+------------+
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136171.17379095947
# --------------------------------------------------------------------------------
# bic: 272366.95
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +---------------------+---------+-------+----------+----------+------------+
# |       Effect        | $\tau$  | Coeff | Std. Err | z-values | Prob |z|>Z |
# +=====================+=========+=======+==========+==========+============+
# | const               | no      | -9.19 |   0.41   |  -22.58  | 0.00***    |
# +---------------------+---------+-------+----------+----------+------------+
# | X1 transaction date | sqrt    | -8.39 |   1.05   |  -8.00   | 0.00***    |
# +---------------------+---------+-------+----------+----------+------------+
# | X2 house age        | arcsinh | -0.08 |   0.41   |  -0.19   | 0.85       |
# +---------------------+---------+-------+----------+----------+------------+
# | X6 longitude        | sqrt    | 35.35 |   4.24   |   8.33   | 0.00***    |
# +---------------------+---------+-------+----------+----------+------------+
# --------------------------------------------------------------------------------
# Log-Likelihood:  -137646.14086899217
# --------------------------------------------------------------------------------
# bic: 275323.91
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +----------------------+---------+----------+----------+----------+------------+
# |        Effect        | $\tau$  |  Coeff   | Std. Err | z-values | Prob |z|>Z |
# +======================+=========+==========+==========+==========+============+
# | const                | no      | -1228.01 |  446.18  |  -2.75   | 0.01*      |
# +----------------------+---------+----------+----------+----------+------------+
# | X2 house age         | no      |  -0.01   |   0.04   |  -0.18   | 0.86       |
# +----------------------+---------+----------+----------+----------+------------+
# | X3 distance to the   | log     |  -0.19   |   0.76   |  -0.25   | 0.81       |
# | nearest MRT station  |         |          |          |          |            |
# +----------------------+---------+----------+----------+----------+------------+
# | X4 number of         | no      |   0.01   |   0.25   |   0.04   | 0.97       |
# | convenience stores   |         |          |          |          |            |
# +----------------------+---------+----------+----------+----------+------------+
# | X5 latitude          | arcsinh |  315.23  |  114.21  |   2.76   | 0.01*      |
# +----------------------+---------+----------+----------+----------+------------+
# zero-size array to reduction operation maximum which has no identity
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136920.22150979695
# --------------------------------------------------------------------------------
# bic: 273871.57
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-----------------------+---------+---------+----------+----------+------------+
# |        Effect         | $\tau$  |  Coeff  | Std. Err | z-values | Prob |z|>Z |
# +=======================+=========+=========+==========+==========+============+
# | const                 | no      | -256.84 |   1.00   |  -50.00  | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | X1 transaction date   | log     | -175.41 |   1.18   |  -50.00  | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | X2 house age          | arcsinh |  -0.08  |   2.81   |  -0.03   | 0.98       |
# +-----------------------+---------+---------+----------+----------+------------+
# | X4 number of          | no      |  0.07   |   0.98   |   0.07   | 0.94       |
# | convenience stores    |         |         |          |          |            |
# +-----------------------+---------+---------+----------+----------+------------+
# | X6 longitude          | log     | 331.71  |   0.00   |  50.00   | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | nb                    |         |  1.00   |   0.00   |  50.00   | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# zero-size array to reduction operation maximum which has no identity
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136155.84495062282
# --------------------------------------------------------------------------------
# bic: 272336.29
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +------------------------+---------+--------+----------+----------+------------+
# |         Effect         | $\tau$  | Coeff  | Std. Err | z-values | Prob |z|>Z |
# +========================+=========+========+==========+==========+============+
# | const                  | no      | -8.49  |   1.00   |  -8.49   | 0.00***    |
# +------------------------+---------+--------+----------+----------+------------+
# | X1 transaction date    | arcsinh | -57.75 |   1.00   |  -50.00  | 0.00***    |
# +------------------------+---------+--------+----------+----------+------------+
# | X3 distance to the     | arcsinh | -0.26  |   3.13   |  -0.08   | 0.93       |
# | nearest MRT station    |         |        |          |          |            |
# +------------------------+---------+--------+----------+----------+------------+
# | X6 longitude           | no      |  4.06  |   0.00   |  50.00   | 0.00***    |
# +------------------------+---------+--------+----------+----------+------------+
# | nb                     |         |  1.00  |   0.00   |  50.00   | 0.00***    |
# +------------------------+---------+--------+----------+----------+------------+
# zero-size array to reduction operation maximum which has no identity
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136500.66815756614
# --------------------------------------------------------------------------------
# bic: 273019.41
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +--------------+--------+---------+----------+----------+------------+
# |    Effect    | $\tau$ |  Coeff  | Std. Err | z-values | Prob |z|>Z |
# +==============+========+=========+==========+==========+============+
# | const        | no     | -42.95  |   1.00   |  -42.95  | 0.00***    |
# +--------------+--------+---------+----------+----------+------------+
# | X5 latitude  | sqrt   | 173.43  |   1.00   |  50.00   | 0.00***    |
# +--------------+--------+---------+----------+----------+------------+
# | X6 longitude | log    | -170.54 |   0.00   |  -50.00  | 0.00***    |
# +--------------+--------+---------+----------+----------+------------+
# | nb           |        |  1.00   |   0.00   |  50.00   | 0.00***    |
# +--------------+--------+---------+----------+----------+------------+
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136371.23964124624
# --------------------------------------------------------------------------------
# bic: 272773.61
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +------------------------+---------+--------+----------+----------+------------+
# |         Effect         | $\tau$  | Coeff  | Std. Err | z-values | Prob |z|>Z |
# +========================+=========+========+==========+==========+============+
# | const                  | no      | -16.69 |   0.10   |  -50.00  | 0.00***    |
# +------------------------+---------+--------+----------+----------+------------+
# | X2 house age           | arcsinh | -0.09  |   0.09   |  -0.95   | 0.34       |
# +------------------------+---------+--------+----------+----------+------------+
# | X3 distance to the     | sqrt    | -0.02  |   0.04   |  -0.49   | 0.62       |
# | nearest MRT station    |         |        |          |          |            |
# +------------------------+---------+--------+----------+----------+------------+
# | X5 latitude            | log     | 271.65 |   0.37   |  50.00   | 0.00***    |
# +------------------------+---------+--------+----------+----------+------------+
# | X6 longitude           | sqrt    | -78.34 |   0.13   |  -50.00  | 0.00***    |
# +------------------------+---------+--------+----------+----------+------------+
# zero-size array to reduction operation maximum which has no identity
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136155.81999038465
# --------------------------------------------------------------------------------
# bic: 272330.72
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-------------------------+---------+-------+----------+----------+------------+
# |         Effect          | $\tau$  | Coeff | Std. Err | z-values | Prob |z|>Z |
# +=========================+=========+=======+==========+==========+============+
# | const                   | no      | 5.87  |  21.51   |   0.27   | 0.78       |
# +-------------------------+---------+-------+----------+----------+------------+
# | X2 house age            | arcsinh | -0.06 |   3.02   |  -0.02   | 0.98       |
# +-------------------------+---------+-------+----------+----------+------------+
# | X3 distance to the      | arcsinh | -0.29 |   0.00   |  -50.00  | 0.00***    |
# | nearest MRT station     |         |       |          |          |            |
# +-------------------------+---------+-------+----------+----------+------------+
# | nb                      |         | 1.00  |   0.00   |  50.00   | 0.00***    |
# +-------------------------+---------+-------+----------+----------+------------+
# zero-size array to reduction operation maximum which has no identity
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136155.59223835488
# --------------------------------------------------------------------------------
# bic: 272336.79
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-------------------------+---------+-------+----------+----------+------------+
# |         Effect          | $\tau$  | Coeff | Std. Err | z-values | Prob |z|>Z |
# +=========================+=========+=======+==========+==========+============+
# | const                   | no      | 0.15  |   1.03   |   0.14   | 0.89       |
# +-------------------------+---------+-------+----------+----------+------------+
# | X2 house age            | arcsinh | -0.07 |   2.88   |  -0.02   | 0.98       |
# +-------------------------+---------+-------+----------+----------+------------+
# | X3 distance to the      | sqrt    | -0.02 |   0.20   |  -0.10   | 0.92       |
# | nearest MRT station     |         |       |          |          |            |
# +-------------------------+---------+-------+----------+----------+------------+
# | X6 longitude            | arcsinh | 0.78  |   0.00   |  50.00   | 0.00***    |
# +-------------------------+---------+-------+----------+----------+------------+
# | nb                      |         | 1.00  |   0.00   |  50.00   | 0.00***    |
# +-------------------------+---------+-------+----------+----------+------------+
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136585.7102217584
# --------------------------------------------------------------------------------
# bic: 273202.55
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-----------------------+---------+---------+----------+----------+------------+
# |        Effect         | $\tau$  |  Coeff  | Std. Err | z-values | Prob |z|>Z |
# +=======================+=========+=========+==========+==========+============+
# | const                 | no      | -52.61  |   0.82   |  -50.00  | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | X3 distance to the    | log     |  -0.23  |   0.73   |  -0.32   | 0.75       |
# | nearest MRT station   |         |         |          |          |            |
# +-----------------------+---------+---------+----------+----------+------------+
# | X4 number of          | no      |  -0.00  |   0.22   |  -0.00   | 1.00       |
# | convenience stores    |         |         |          |          |            |
# +-----------------------+---------+---------+----------+----------+------------+
# | X5 latitude           | arcsinh | 268.41  |   1.19   |  50.00   | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | X6 longitude          | log     | -206.32 |   0.91   |  -50.00  | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136699.33235339558
# --------------------------------------------------------------------------------
# bic: 273423.77
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-----------------------+---------+---------+----------+----------+------------+
# |        Effect         | $\tau$  |  Coeff  | Std. Err | z-values | Prob |z|>Z |
# +=======================+=========+=========+==========+==========+============+
# | const                 | no      | -583.22 |   0.50   |  -50.00  | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | X1 transaction date   | sqrt    |  13.11  |   0.22   |  50.00   | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | X3 distance to the    | arcsinh |  -0.21  |   1.33   |  -0.16   | 0.87       |
# | nearest MRT station   |         |         |          |          |            |
# +-----------------------+---------+---------+----------+----------+------------+
# ...
# +-----------------------+---------+---------+----------+----------+------------+
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136582.03535348806
# --------------------------------------------------------------------------------
# bic: 273201.73
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-----------------------+---------+---------+----------+----------+------------+
# |        Effect         | $\tau$  |  Coeff  | Std. Err | z-values | Prob |z|>Z |
# +=======================+=========+=========+==========+==========+============+
# | const                 | no      | -50.36  |   0.91   |  -50.00  | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | X2 house age          | arcsinh |  -0.09  |   0.41   |  -0.22   | 0.83       |
# +-----------------------+---------+---------+----------+----------+------------+
# | X3 distance to the    | sqrt    |  -0.02  |   0.05   |  -0.31   | 0.76       |
# | nearest MRT station   |         |         |          |          |            |
# +-----------------------+---------+---------+----------+----------+------------+
# | X4 number of          | arcsinh |  0.03   |   0.52   |   0.05   | 0.96       |
# | convenience stores    |         |         |          |          |            |
# +-----------------------+---------+---------+----------+----------+------------+
# | X5 latitude           | arcsinh | 272.91  |   0.94   |  50.00   | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | X6 longitude          | log     | -210.62 |   0.93   |  -50.00  | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136274.5916072501
# --------------------------------------------------------------------------------
# bic: 272575.29
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +------------------------+--------+---------+----------+----------+------------+
# |         Effect         | $\tau$ |  Coeff  | Std. Err | z-values | Prob |z|>Z |
# +========================+========+=========+==========+==========+============+
# | const                  | no     | -21.85  |  87.52   |  -0.25   | 0.80       |
# +------------------------+--------+---------+----------+----------+------------+
# | X1 transaction date    | log    | -145.77 |  583.83  |  -0.25   | 0.80       |
# +------------------------+--------+---------+----------+----------+------------+
# | X4 number of           | no     |  0.06   |   0.16   |   0.35   | 0.73       |
# | convenience stores     |        |         |          |          |            |
# +------------------------+--------+---------+----------+----------+------------+
# | X6 longitude           | no     |  9.33   |  37.27   |   0.25   | 0.80       |
# +------------------------+--------+---------+----------+----------+------------+
# zero-size array to reduction operation maximum which has no identity
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136604.5239798315
# --------------------------------------------------------------------------------
# bic: 273233.65
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-----------------------+---------+---------+----------+----------+------------+
# |        Effect         | $\tau$  |  Coeff  | Std. Err | z-values | Prob |z|>Z |
# +=======================+=========+=========+==========+==========+============+
# | const                 | no      | -42.06  |   1.09   |  -38.45  | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | X3 distance to the    | log     |  -0.25  |   3.13   |  -0.08   | 0.94       |
# | nearest MRT station   |         |         |          |          |            |
# +-----------------------+---------+---------+----------+----------+------------+
# | X5 latitude           | log     | 287.23  |   1.76   |  50.00   | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | X6 longitude          | arcsinh | -161.69 |   0.00   |  -50.00  | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# | nb                    |         |  1.00   |   0.00   |  50.00   | 0.00***    |
# +-----------------------+---------+---------+----------+----------+------------+
# The number of imps is 67 the max imps is 90000000  elapsed time is 6.04916 max time 6 no improvement 3 max_improvement 10000
# best_re [{'gen': 0, 'fitness': {'aic': np.float64(272224.12268343114), 'bic': np.float64(272241.72614732647), 'MAE': 10000000.0, 'MSE': 10000000.0, 'MAE_TEST': 10000000.0, 'MSE_TEST': 10000000.0, 'MAE_VAL': 10000000.0, 'MSE_VAL': 10000000.0, 'RMSE_VAL': 10000000.0, 'RMSE_TEST': 10000000.0, 'RMSE': 10000000.0, 'layout': [1, 0, 1, 1, 0, 0, 1, 'triangular', 'uniform', 'ln_normal', 'triangular', 'triangular', 'normal', 'uniform', 'no', 'sqrt', 'arcsinh', 'sqrt', 'arcsinh', 'log', 'log', 0], 'sol_num': 38, 'num_parm': 4, 'pval_exceed': 3, 'pval_percentage': 0.75, 'loglik': np.float64(-136108.06134171557), 'simple': 'f_p', 'fixed_fit': ['const', 'X2 house age', 'X3 distance to the nearest MRT station', 'X6 longitude'], 'rdm_fit': [], 'rdm_cor_fit': [], 'zi_fit': None, 'pvalues': array([0.8507976 , 0.88583971, 0.61134519, 0.01846375]), 'CAIC': np.float64(272240.23579751205), 'DIC': np.float64(272227.5332091508), 'HQIC': np.float64(272230.4911730243), 'AICc': np.float64(272224.2204829421)}}, {'gen': 1, 'fitness': {'aic': np.float64(272249.5573508197), 'bic': np.float64(272267.660814715), 'MAE': 10000000.0, 'MSE': 10000000.0, 'MAE_TEST': 10000000.0, 'MSE_TEST': 10000000.0, 'MAE_VAL': 10000000.0, 'MSE_VAL': 10000000.0, 'RMSE_VAL': 10000000.0, 'RMSE_TEST': 10000000.0, 'RMSE': 10000000.0, 'layout': [1, 1, 0, 1, 0, 0, 1, 'triangular', 'tn_normal', 'uniform', 'triangular', 'normal', 'triangular', 'tn_normal', 'no', 'arcsinh', 'arcsinh', 'arcsinh', 'no', 'sqrt', 'arcsinh', 0], 'sol_num': 80, 'num_parm': 4, 'pval_exceed': 4, 'pval_percentage': 1.0, 'loglik': np.float64(-136120.77867540985), 'simple': 'f_p', 'fixed_fit': ['const', 'X1 transaction date', 'X3 distance to the nearest MRT station', 'X6 longitude'], 'rdm_fit': [], 'rdm_cor_fit': [], 'zi_fit': None, 'pvalues': array([0.95831059, 0.46125244, 0.59764997, 0.71897581]), 'CAIC': np.float64(272265.6704649006), 'DIC': np.float64(272252.96787653933), 'HQIC': np.float64(272255.92584041285), 'AICc': np.float64(272249.6551503307)}}, {'gen': 2, 'fitness': {'aic': np.float64(272230.48373091826), 'bic': np.float64(272243.56132883974), 'MAE': 10000000.0, 'MSE': 10000000.0, 'MAE_TEST': 10000000.0, 'MSE_TEST': 10000000.0, 'MAE_VAL': 10000000.0, 'MSE_VAL': 10000000.0, 'RMSE_VAL': 10000000.0, 'RMSE_TEST': 10000000.0, 'RMSE': 10000000.0, 'layout': [1, 0, 0, 1, 0, 0, 1, 'normal', 'normal', 'ln_normal', 'uniform', 'triangular', 'tn_normal', 'tn_normal', 'no', 'sqrt', 'arcsinh', 'sqrt', 'no', 'log', 'sqrt', 0], 'sol_num': 99, 'num_parm': 3, 'pval_exceed': 2, 'pval_percentage': 0.6666666666666666, 'loglik': np.float64(-136112.24186545913), 'simple': 'f_p', 'fixed_fit': ['const', 'X3 distance to the nearest MRT station', 'X6 longitude'], 'rdm_fit': [], 'rdm_cor_fit': [], 'zi_fit': None, 'pvalues': array([0.97031465, 0.60150517, 0.00312268]), 'CAIC': np.float64(272242.56856647896), 'DIC': np.float64(272233.041625208), 'HQIC': np.float64(272235.26009811315), 'AICc': np.float64(272230.5422675036)}}]
# [0, 1, 2]
# [{'aic': np.float64(272224.12268343114), 'bic': np.float64(272241.72614732647), 'MAE': 10000000.0, 'MSE': 10000000.0, 'MAE_TEST': 10000000.0, 'MSE_TEST': 10000000.0, 'MAE_VAL': 10000000.0, 'MSE_VAL': 10000000.0, 'RMSE_VAL': 10000000.0, 'RMSE_TEST': 10000000.0, 'RMSE': 10000000.0, 'layout': [1, 0, 1, 1, 0, 0, 1, 'triangular', 'uniform', 'ln_normal', 'triangular', 'triangular', 'normal', 'uniform', 'no', 'sqrt', 'arcsinh', 'sqrt', 'arcsinh', 'log', 'log', 0], 'sol_num': 38, 'num_parm': 4, 'pval_exceed': 3, 'pval_percentage': 0.75, 'loglik': np.float64(-136108.06134171557), 'simple': 'f_p', 'fixed_fit': ['const', 'X2 house age', 'X3 distance to the nearest MRT station', 'X6 longitude'], 'rdm_fit': [], 'rdm_cor_fit': [], 'zi_fit': None, 'pvalues': array([0.8507976 , 0.88583971, 0.61134519, 0.01846375]), 'CAIC': np.float64(272240.23579751205), 'DIC': np.float64(272227.5332091508), 'HQIC': np.float64(272230.4911730243), 'AICc': np.float64(272224.2204829421)}, {'aic': np.float64(272249.5573508197), 'bic': np.float64(272267.660814715), 'MAE': 10000000.0, 'MSE': 10000000.0, 'MAE_TEST': 10000000.0, 'MSE_TEST': 10000000.0, 'MAE_VAL': 10000000.0, 'MSE_VAL': 10000000.0, 'RMSE_VAL': 10000000.0, 'RMSE_TEST': 10000000.0, 'RMSE': 10000000.0, 'layout': [1, 1, 0, 1, 0, 0, 1, 'triangular', 'tn_normal', 'uniform', 'triangular', 'normal', 'triangular', 'tn_normal', 'no', 'arcsinh', 'arcsinh', 'arcsinh', 'no', 'sqrt', 'arcsinh', 0], 'sol_num': 80, 'num_parm': 4, 'pval_exceed': 4, 'pval_percentage': 1.0, 'loglik': np.float64(-136120.77867540985), 'simple': 'f_p', 'fixed_fit': ['const', 'X1 transaction date', 'X3 distance to the nearest MRT station', 'X6 longitude'], 'rdm_fit': [], 'rdm_cor_fit': [], 'zi_fit': None, 'pvalues': array([0.95831059, 0.46125244, 0.59764997, 0.71897581]), 'CAIC': np.float64(272265.6704649006), 'DIC': np.float64(272252.96787653933), 'HQIC': np.float64(272255.92584041285), 'AICc': np.float64(272249.6551503307)}, {'aic': np.float64(272230.48373091826), 'bic': np.float64(272243.56132883974), 'MAE': 10000000.0, 'MSE': 10000000.0, 'MAE_TEST': 10000000.0, 'MSE_TEST': 10000000.0, 'MAE_VAL': 10000000.0, 'MSE_VAL': 10000000.0, 'RMSE_VAL': 10000000.0, 'RMSE_TEST': 10000000.0, 'RMSE': 10000000.0, 'layout': [1, 0, 0, 1, 0, 0, 1, 'normal', 'normal', 'ln_normal', 'uniform', 'triangular', 'tn_normal', 'tn_normal', 'no', 'sqrt', 'arcsinh', 'sqrt', 'no', 'log', 'sqrt', 0], 'sol_num': 99, 'num_parm': 3, 'pval_exceed': 2, 'pval_percentage': 0.6666666666666666, 'loglik': np.float64(-136112.24186545913), 'simple': 'f_p', 'fixed_fit': ['const', 'X3 distance to the nearest MRT station', 'X6 longitude'], 'rdm_fit': [], 'rdm_cor_fit': [], 'zi_fit': None, 'pvalues': array([0.97031465, 0.60150517, 0.00312268]), 'CAIC': np.float64(272242.56856647896), 'DIC': np.float64(272233.041625208), 'HQIC': np.float64(272235.26009811315), 'AICc': np.float64(272230.5422675036)}]
# [0, 1, 2]
# [{'aic': np.float64(272224.12268343114), 'bic': np.float64(272241.72614732647), 'MAE': 10000000.0, 'MSE': 10000000.0, 'MAE_TEST': 10000000.0, 'MSE_TEST': 10000000.0, 'MAE_VAL': 10000000.0, 'MSE_VAL': 10000000.0, 'RMSE_VAL': 10000000.0, 'RMSE_TEST': 10000000.0, 'RMSE': 10000000.0, 'layout': [1, 0, 1, 1, 0, 0, 1, 'triangular', 'uniform', 'ln_normal', 'triangular', 'triangular', 'normal', 'uniform', 'no', 'sqrt', 'arcsinh', 'sqrt', 'arcsinh', 'log', 'log', 0], 'sol_num': 38, 'num_parm': 4, 'pval_exceed': 3, 'pval_percentage': 0.75, 'loglik': np.float64(-136108.06134171557), 'simple': 'f_p', 'fixed_fit': ['const', 'X2 house age', 'X3 distance to the nearest MRT station', 'X6 longitude'], 'rdm_fit': [], 'rdm_cor_fit': [], 'zi_fit': None, 'pvalues': array([0.8507976 , 0.88583971, 0.61134519, 0.01846375]), 'CAIC': np.float64(272240.23579751205), 'DIC': np.float64(272227.5332091508), 'HQIC': np.float64(272230.4911730243), 'AICc': np.float64(272224.2204829421)}, {'aic': np.float64(272224.12268343114), 'bic': np.float64(272241.72614732647), 'MAE': 10000000.0, 'MSE': 10000000.0, 'MAE_TEST': 10000000.0, 'MSE_TEST': 10000000.0, 'MAE_VAL': 10000000.0, 'MSE_VAL': 10000000.0, 'RMSE_VAL': 10000000.0, 'RMSE_TEST': 10000000.0, 'RMSE': 10000000.0, 'layout': [1, 0, 1, 1, 0, 0, 1, 'triangular', 'uniform', 'ln_normal', 'triangular', 'triangular', 'normal', 'uniform', 'no', 'sqrt', 'arcsinh', 'sqrt', 'arcsinh', 'log', 'log', 0], 'sol_num': 38, 'num_parm': 4, 'pval_exceed': 3, 'pval_percentage': 0.75, 'loglik': np.float64(-136108.06134171557), 'simple': 'f_p', 'fixed_fit': ['const', 'X2 house age', 'X3 distance to the nearest MRT station', 'X6 longitude'], 'rdm_fit': [], 'rdm_cor_fit': [], 'zi_fit': None, 'pvalues': array([0.8507976 , 0.88583971, 0.61134519, 0.01846375]), 'CAIC': np.float64(272240.23579751205), 'DIC': np.float64(272227.5332091508), 'HQIC': np.float64(272230.4911730243), 'AICc': np.float64(272224.2204829421)}, {'aic': np.float64(272224.12268343114), 'bic': np.float64(272241.72614732647), 'MAE': 10000000.0, 'MSE': 10000000.0, 'MAE_TEST': 10000000.0, 'MSE_TEST': 10000000.0, 'MAE_VAL': 10000000.0, 'MSE_VAL': 10000000.0, 'RMSE_VAL': 10000000.0, 'RMSE_TEST': 10000000.0, 'RMSE': 10000000.0, 'layout': [1, 0, 1, 1, 0, 0, 1, 'triangular', 'uniform', 'ln_normal', 'triangular', 'triangular', 'normal', 'uniform', 'no', 'sqrt', 'arcsinh', 'sqrt', 'arcsinh', 'log', 'log', 0], 'sol_num': 38, 'num_parm': 4, 'pval_exceed': 3, 'pval_percentage': 0.75, 'loglik': np.float64(-136108.06134171557), 'simple': 'f_p', 'fixed_fit': ['const', 'X2 house age', 'X3 distance to the nearest MRT station', 'X6 longitude'], 'rdm_fit': [], 'rdm_cor_fit': [], 'zi_fit': None, 'pvalues': array([0.8507976 , 0.88583971, 0.61134519, 0.01846375]), 'CAIC': np.float64(272240.23579751205), 'DIC': np.float64(272227.5332091508), 'HQIC': np.float64(272230.4911730243), 'AICc': np.float64(272224.2204829421)}]
# yes
# best harmony [1, 0, 1, 1, 0, 0, 1, 'triangular', 'uniform', 'ln_normal', 'triangular', 'triangular', 'normal', 'uniform', 'no', 'sqrt', 'arcsinh', 'sqrt', 'arcsinh', 'log', 'log', 0]
# --------------------------------------------------------------------------------
# Log-Likelihood:  -136108.06134175777
# --------------------------------------------------------------------------------
# bic: 272241.73
# --------------------------------------------------------------------------------
# MAE: 10000000.00
# +-------------------------+---------+-------+----------+----------+------------+
# |         Effect          | $\tau$  | Coeff | Std. Err | z-values | Prob |z|>Z |
# +=========================+=========+=======+==========+==========+============+
# | const                   | no      | 0.19  |   1.15   |   0.16   | 0.87       |
# +-------------------------+---------+-------+----------+----------+------------+
# | X2 house age            | arcsinh | -0.06 |   0.37   |  -0.16   | 0.87       |
# +-------------------------+---------+-------+----------+----------+------------+
# | X3 distance to the      | sqrt    | -0.02 |   0.04   |  -0.57   | 0.57       |
# | nearest MRT station     |         |       |          |          |            |
# +-------------------------+---------+-------+----------+----------+------------+
# | X6 longitude            | log     | 0.88  |   0.36   |   2.41   | 0.02*      |
# +-------------------------+---------+-------+----------+----------+------------+
# The best solution iteratively is of objective value: {'aic': np.float64(272224.12268351554), 'bic': np.float64(272241.72614741087), 'MAE': 10000000.0, 'MSE': 10000000.0, 'MAE_TEST': 10000000.0, 'MSE_TEST': 10000000.0, 'MAE_VAL': 10000000.0, 'MSE_VAL': 10000000.0, 'RMSE_VAL': 10000000.0, 'RMSE_TEST': 10000000.0, 'RMSE': 10000000.0, 'layout': [1, 0, 1, 1, 0, 0, 1, 'triangular', 'uniform', 'ln_normal', 'triangular', 'triangular', 'normal', 'uniform', 'no', 'sqrt', 'arcsinh', 'sqrt', 'arcsinh', 'log', 'log', 0], 'sol_num': 115, 'num_parm': 4, 'pval_exceed': 3, 'pval_percentage': 0.75, 'loglik': np.float64(-136108.06134175777), 'simple': 'f_p', 'fixed_fit': ['const', 'X2 house age', 'X3 distance to the nearest MRT station', 'X6 longitude'], 'rdm_fit': [], 'rdm_cor_fit': [], 'zi_fit': None, 'pvalues': array([0.87194636, 0.87168668, 0.56660178, 0.01629405]), 'CAIC': np.float64(272240.23579759646), 'DIC': np.float64(272227.5332092352), 'HQIC': np.float64(272230.4911731087), 'AICc': np.float64(272224.2204830265)}
